# %%
#https://www.kaggle.com/code/sangrampatil5150/nuralbrain-v0-5-1-model-train-and-win
import numpy as np
from collections import deque
import torch
import torch.nn as nn
import torch.nn.functional as F

class ReplayBuffer:
    def __init__(self, capacity, alpha=0.6, beta_start=0.4, beta_frames=100000):
        self.capacity = capacity
        self.buffer = deque(maxlen=capacity)
        self.priorities = deque(maxlen=capacity)
        self.alpha = alpha
        self.beta_start = beta_start
        self.beta_frames = beta_frames
        self.frame = 1  # Used for beta annealing

    def push(self, state, action, reward, next_state, done):
        # New experience: assign maximum priority so that new transitions are sampled at least once.
        if self.priorities:
            max_priority = np.max([np.max(p) if isinstance(p, np.ndarray) else p for p in self.priorities])
        else:
            max_priority = 1.0
        self.buffer.append((state, action, reward, next_state, done))
        self.priorities.append(max_priority)

    def sample(self, batch_size):
        beta = min(1.0, self.beta_start + self.frame * (1.0 - self.beta_start) / self.beta_frames)
        self.frame += 1

        priorities = np.array([np.max(p) if isinstance(p, np.ndarray) else p for p in self.priorities], dtype=np.float32)
        probs = priorities ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs, replace=False)
        samples = [self.buffer[idx] for idx in indices]

        weights = (len(self.buffer) * probs[indices]) ** (-beta)
        weights /= weights.max()  # Normalize to stabilize learning
        weights = torch.FloatTensor(weights).to(samples[0][0].device)
        return samples, indices, weights

    def update_priorities(self, indices, errors):
        for idx, error in zip(indices, errors):
            self.priorities[idx] = (abs(error) + 1e-5) ** self.alpha

    def __len__(self):
        return len(self.buffer)

class DQN(nn.Module):
    def __init__(self, input_channels, output_size, local_view_size, hidden_size=512):
        super(DQN, self).__init__()
        self.local_view_size = local_view_size

        # Convolutional layers.
        self.conv1 = nn.Conv2d(input_channels, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(256)

        # Pooling layer.
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Compute the flattened feature size.
        self._conv_output_size = self._get_conv_output_size(input_channels)

        # Fully-connected layers.
        self.fc1 = nn.Linear(self._conv_output_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)

    def _get_conv_output_size(self, input_channels):
        _input = torch.zeros(1, input_channels, self.local_view_size, self.local_view_size)
        x = self.pool(F.relu(self.bn1(self.conv1(_input))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        return int(np.prod(x.size()))

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)  # Flatten
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
import random
import numpy as np
import torch
import copy
from collections import deque
from enum import IntEnum
from scipy.signal import convolve2d
from torch.optim.lr_scheduler import StepLR

# Global configuration
SPACE_SIZE = 24  # Map size constant

class Global:
    MAX_UNITS = 16
    RELIC_REWARD_RANGE = 5
    ALL_RELICS_FOUND = False
    ALL_REWARDS_FOUND = False
    LAST_MATCH_WHEN_RELIC_CAN_APPEAR = 10
    LAST_MATCH_STEP_WHEN_RELIC_CAN_APPEAR = 0
    REWARD_RESULTS = []
    OBSTACLES_MOVEMENT_STATUS = []
    OBSTACLE_MOVEMENT_DIRECTION_FOUND = False
    OBSTACLE_MOVEMENT_DIRECTION = (0, 0)
    OBSTACLE_MOVEMENT_PERIOD_FOUND = False
    OBSTACLE_MOVEMENT_PERIOD = 0

def get_opposite(x, y):
    """Returns the symmetrical opposite coordinates on the map."""
    return SPACE_SIZE - 1 - x, SPACE_SIZE - 1 - y

def warp_point(x, y):
    return x % SPACE_SIZE, y % SPACE_SIZE

def nearby_positions(x, y, radius):
    """Yields positions within a given radius of (x, y)."""
    for dx in range(-radius, radius + 1):
        for dy in range(-radius, radius + 1):
            nx, ny = warp_point(x + dx, y + dy)
            yield nx, ny

def get_match_number(step):
    return step // 505

def get_match_step(step):
    return step % 505

def manhattan_distance(a, b) -> int:
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

_DIRECTIONS = [
    (0, 0),    # center
    (0, -1),   # up
    (1, 0),    # right
    (0, 1),    # down
    (-1, 0),   # left
    (0, 0),    # sap
]

class ActionType(IntEnum):
    center = 0
    up = 1
    right = 2
    down = 3
    left = 4
    sap = 5

    def __str__(self):
        return self.name

    def __repr__(self):
        return self.name

    @classmethod
    def from_coordinates(cls, current_position, next_position):
        dx = next_position[0] - current_position[0]
        dy = next_position[1] - current_position[1]
        if dx < 0:
            return ActionType.left
        elif dx > 0:
            return ActionType.right
        elif dy < 0:
            return ActionType.up
        elif dy > 0:
            return ActionType.down
        else:
            return ActionType.center

    def to_direction(self):
        return _DIRECTIONS[self]

class NodeType(IntEnum):
    unknown = -1
    empty = 0
    nebula = 1
    asteroid = 2

    def __str__(self):
        return self.name

    def __repr__(self):
        return self.name

class Node:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.type = NodeType.unknown
        self.energy = None
        self.is_visible = False

        self._relic = False
        self._reward = False
        self._explored_for_relic = False
        self._explored_for_reward = False

    def __repr__(self):
        return f"Node({self.x}, {self.y}, {self.type})"

    def __hash__(self):
        return self.coordinates.__hash__()

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y

    @property
    def relic(self):
        return self._relic

    @property
    def reward(self):
        return self._reward

    @property
    def explored_for_relic(self):
        return self._explored_for_relic

    @property
    def explored_for_reward(self):
        return self._explored_for_reward

    def update_relic_status(self, status: None | bool):
        if self._explored_for_relic and self._relic and not status:
            raise ValueError(
                f"Can't change the relic status {self._relic}->{status} for {self}"
                ", the tile has already been explored"
            )
        if status is None:
            self._explored_for_relic = False
            return
        self._relic = status
        self._explored_for_relic = True

    def update_reward_status(self, status: None | bool):
        if self._explored_for_reward and self._reward and not status:
            self._explored_for_reward = False
        if status is None:
            self._explored_for_reward = False
            return
        self._reward = status
        self._explored_for_reward = True

    @property
    def is_unknown(self) -> bool:
        return self.type == NodeType.unknown

    @property
    def is_walkable(self) -> bool:
        return self.type != NodeType.asteroid

    @property
    def coordinates(self) -> tuple[int, int]:
        return self.x, self.y

    def manhattan_distance(self, other: "Node") -> int:
        return abs(self.x - other.x) + abs(self.y - other.y)

class Space:
    def __init__(self, space_size):
        self.space_size = space_size
        self._nodes: list[list[Node]] = []
        for y in range(self.space_size):
            row = [Node(x, y) for x in range(self.space_size)]
            self._nodes.append(row)
        self._relic_nodes: set[Node] = set()
        self._reward_nodes: set[Node] = set()
        self.obstacle_history = deque(maxlen=100)
        self.best_direction = (0, 0)
        self.best_period = 40
        self.movement_counter = 0

    def __repr__(self) -> str:
        return f"Space({self.space_size}x{self.space_size})"

    def __iter__(self):
        for row in self._nodes:
            yield from row

    @property
    def relic_nodes(self) -> set[Node]:
        return self._relic_nodes

    @property
    def reward_nodes(self) -> set[Node]:
        return self._reward_nodes

    def get_node(self, x, y) -> Node:
        return self._nodes[y][x]

    def update(self, step, obs, team_id, team_reward):
        self.move_obstacles(step)
        self._update_map(obs)
        self._update_relic_map(step, obs, team_id, team_reward)

    def _update_relic_map(self, step, obs, team_id, team_reward):
        for mask, xy in zip(obs["relic_nodes_mask"], obs["relic_nodes"]):
            if mask and not self.get_node(*xy).relic:
                self._update_relic_status(*xy, status=True)
                for x, y in nearby_positions(*xy, Global.RELIC_REWARD_RANGE):
                    if not self.get_node(x, y).reward:
                        self._update_reward_status(x, y, status=None)
        all_relics_found = True
        all_rewards_found = True
        for node in self:
            if node.is_visible and not node.explored_for_relic:
                self._update_relic_status(*node.coordinates, status=False)
            if not node.explored_for_relic:
                all_relics_found = False
            if not node.explored_for_reward:
                all_rewards_found = False
        Global.ALL_RELICS_FOUND = all_relics_found
        Global.ALL_REWARDS_FOUND = all_rewards_found
        match = get_match_number(step)
        match_step = get_match_step(step)
        num_relics_th = 2 * min(match, Global.LAST_MATCH_WHEN_RELIC_CAN_APPEAR) + 1
        if not Global.ALL_RELICS_FOUND:
            if len(self._relic_nodes) >= num_relics_th:
                Global.ALL_RELICS_FOUND = True
                for node in self:
                    if not node.explored_for_relic:
                        self._update_relic_status(*node.coordinates, status=False)
        if not Global.ALL_REWARDS_FOUND:
            if (
                match_step > Global.LAST_MATCH_STEP_WHEN_RELIC_CAN_APPEAR
                or len(self._relic_nodes) >= num_relics_th
            ):
                self._update_reward_status_from_relics_distribution()
                self._update_reward_results(obs, team_id, team_reward)
                self._update_reward_status_from_reward_results()

    def _update_reward_status_from_reward_results(self):
        for result in Global.REWARD_RESULTS:
            unknown_nodes = set()
            known_reward = 0
            for n in result["nodes"]:
                if n.explored_for_reward and not n.reward:
                    continue
                if n.reward:
                    known_reward += 1
                    continue
                unknown_nodes.add(n)
            if not unknown_nodes:
                continue
            reward = result["reward"] - known_reward
            if reward == 0:
                for node in unknown_nodes:
                    self._update_reward_status(*node.coordinates, status=False)
            elif reward == len(unknown_nodes):
                for node in unknown_nodes:
                    self._update_reward_status(*node.coordinates, status=True)
            elif reward > len(unknown_nodes):
                pass

    def _update_reward_results(self, obs, team_id, team_reward):
        ship_nodes = set()
        for active, energy, position in zip(
            obs["units_mask"][team_id],
            obs["units"]["energy"][team_id],
            obs["units"]["position"][team_id],
        ):
            if active and energy >= 0:
                ship_nodes.add(self.get_node(*position))
        Global.REWARD_RESULTS.append({"nodes": ship_nodes, "reward": team_reward})

    def _update_reward_status_from_relics_distribution(self):
        relic_map = np.zeros((self.space_size, self.space_size), np.int32)
        for node in self:
            if node.relic or not node.explored_for_relic:
                relic_map[node.y][node.x] = 1
        reward_size = 2 * Global.RELIC_REWARD_RANGE + 1
        reward_map = convolve2d(
            relic_map,
            np.ones((reward_size, reward_size), dtype=np.int32),
            mode="same",
            boundary="fill",
            fillvalue=0,
        )
        for node in self:
            if reward_map[node.y][node.x] == 0:
                node.update_reward_status(False)

    def _update_relic_status(self, x, y, status):
        node = self.get_node(x, y)
        node.update_relic_status(status)
        opp_node = self.get_node(*get_opposite(x, y))
        opp_node.update_relic_status(status)
        if status:
            self._relic_nodes.add(node)
            self._relic_nodes.add(opp_node)

    def _update_reward_status(self, x, y, status):
        node = self.get_node(x, y)
        node.update_reward_status(status)
        opp_node = self.get_node(*get_opposite(x, y))
        opp_node.update_reward_status(status)
        if status:
            self._reward_nodes.add(node)
            self._reward_nodes.add(opp_node)

    def _update_map(self, obs):
        current_obstacles = np.zeros((self.space_size, self.space_size), dtype=bool)
        for node in self:
            if node.type == NodeType.asteroid:
                current_obstacles[node.y, node.x] = True
        self.obstacle_history.append(current_obstacles)
        sensor_mask = obs["sensor_mask"]
        obs_energy = obs["map_features"]["energy"]
        obs_tile_type = obs["map_features"]["tile_type"]
        for node in self:
            x, y = node.coordinates
            is_visible = bool(sensor_mask[x, y])
            node.is_visible = is_visible
            if is_visible:
                node.type = NodeType(int(obs_tile_type[x, y]))
                self.get_node(*get_opposite(x, y)).type = node.type
                node.energy = int(obs_energy[x, y])
                self.get_node(*get_opposite(x, y)).energy = node.energy
            elif node.energy is not None:
                node.energy = None
        self.movement_counter += 1
        if self.movement_counter >= self.best_period:
            self.update_obstacle_movement_prediction()
            self.movement_counter = 0

    def update_obstacle_movement_prediction(self):
        best_direction = (0, 0)
        best_period = 0
        best_match_score = -1
        for period in [10, 20, 40]:
            for direction in [(0, 1), (0, -1), (1, 0), (-1, 0)]:
                match_score = self.calculate_match_score(direction, period)
                if match_score > best_match_score:
                    best_match_score = match_score
                    best_direction = direction
                    best_period = period
        if best_match_score > 0.5:
            self.best_direction = best_direction
            self.best_period = best_period

    def calculate_match_score(self, direction, period):
        if len(self.obstacle_history) < period:
            return 0
        past_obstacles = self.obstacle_history[-period]
        moved_past_obstacles = self.move_obstacles_array(past_obstacles, direction)
        current_obstacles = self.obstacle_history[-1]
        matches = np.sum(moved_past_obstacles == current_obstacles)
        total_tiles = self.space_size * self.space_size
        match_score = matches / total_tiles
        return match_score

    def move_obstacles_array(self, obstacles, direction):
        dx, dy = direction
        moved_obstacles = np.copy(obstacles)
        moved_obstacles = np.roll(moved_obstacles, shift=(dy, dx), axis=(0, 1))
        return moved_obstacles

    def clear(self):
        for node in self:
            node.is_visible = False

    def move_obstacles(self, step):
        if self.best_period > 0:
            speed = 1.0 / self.best_period
            if (step - 1) * speed % 1 > step * speed % 1:
                self.move(*self.best_direction, inplace=True)

    def move(self, dx: int, dy: int, *, inplace=False) -> "Space":
        if not inplace:
            new_space = copy.deepcopy(self)
            for node in self:
                x, y = warp_point(node.x + dx, node.y + dy)
                new_space.get_node(x, y).type = node.type
            return new_space
        else:
            types = [n.type for n in self]
            for node, node_type in zip(self, types):
                x, y = warp_point(node.x + dx, node.y + dy)
                self.get_node(x, y).type = node_type
            return self

    def clear_exploration_info(self):
        Global.REWARD_RESULTS = []
        Global.ALL_RELICS_FOUND = False
        Global.ALL_REWARDS_FOUND = False
        for node in self:
            if not node.relic:
                self._update_relic_status(node.x, node.y, status=None)

class Ship:
    def __init__(self, unit_id: int):
        self.unit_id = unit_id
        self.energy = 0
        self.node: Node | None = None
        self.task: str | None = None
        self.target: Node | None = None
        self.action: ActionType | tuple | None = None

    def __repr__(self):
        return f"Ship({self.unit_id}, node={self.node.coordinates if self.node else None}, energy={self.energy})"

    @property
    def coordinates(self):
        return self.node.coordinates if self.node else None

    def clean(self):
        self.energy = 0
        self.node = None
        self.task = None
        self.target = None
        self.action = None

class Fleet:
    def __init__(self, team_id):
        self.team_id: int = team_id
        self.points: int = 0
        self.ships = [Ship(unit_id) for unit_id in range(Global.MAX_UNITS)]

    def __repr__(self):
        return f"Fleet({self.team_id})"

    def __iter__(self):
        for ship in self.ships:
            if ship.node is not None:
                yield ship

    def clear(self):
        self.points = 0
        for ship in self.ships:
            ship.clean()

    def update(self, obs, space: Space):
        self.points = int(obs["team_points"][self.team_id])
        for ship, active, position, energy in zip(
            self.ships,
            obs["units_mask"][self.team_id],
            obs["units"]["position"][self.team_id],
            obs["units"]["energy"][self.team_id],
        ):
            if active:
                ship.node = space.get_node(*position)
                ship.energy = int(energy)
                ship.action = None
            else:
                ship.clean()

class Agent:
    def __init__(self, player: str, env_cfg, training=True) -> None:
        self.player = player
        self.opp_player = "player_1" if self.player == "player_0" else "player_0"
        self.team_id = 0 if self.player == "player_0" else 1
        self.opp_team_id = 1 if self.team_id == 0 else 0
        self.env_cfg = env_cfg
        self.training = training
        self.map_width = env_cfg["map_width"]
        self.map_height = env_cfg["map_height"]
        self.UNIT_MOVE_COST = env_cfg["unit_move_cost"]
        self.UNIT_SAP_COST = env_cfg["unit_sap_cost"]
        self.UNIT_SAP_RANGE = env_cfg["unit_sap_range"]
        self.UNIT_SENSOR_RANGE = env_cfg["unit_sensor_range"]

        self.space = Space(self.map_width)
        self.fleet = Fleet(self.team_id)
        self.opp_fleet = Fleet(self.opp_team_id)

        # --- DQN Parameters ---
        self.local_view_size = 11
        self.input_channels = 9
        self.action_size = 5
        self.hidden_size = 512
        self.batch_size = 128
        self.gamma = 0.99
        self.epsilon_start = 1.0
        self.epsilon_min = 0.05
        self.epsilon_decay = 0.9995
        self.learning_rate = 0.0001
        self.replay_buffer_capacity = 50000
        self.beta_frames = 200000
        self.frame_count = 1

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(self.input_channels, self.action_size, self.local_view_size, self.hidden_size).to(self.device)
        self.target_net = DQN(self.input_channels, self.action_size, self.local_view_size, self.hidden_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        import torch.optim as optim
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate, weight_decay=1e-5)
        self.memory = ReplayBuffer(self.replay_buffer_capacity, beta_frames=self.beta_frames)
        self.epsilon = self.epsilon_start

        from torch.optim.lr_scheduler import StepLR
        self.scheduler = StepLR(self.optimizer, step_size=10000, gamma=0.1)

        if not training:
            self.load_model()
            self.epsilon = 0.0

        self.unit_explore_locations = dict()

    def _state_representation(self, unit_pos, unit_energy, step, obs):
        local_view_size = self.local_view_size
        pad_width = local_view_size // 2

        tile_type_channel = np.zeros((local_view_size, local_view_size))
        energy_channel = np.zeros((local_view_size, local_view_size))
        relic_channel = np.zeros((local_view_size, local_view_size))
        reward_channel = np.zeros((local_view_size, local_view_size))
        units_channel = np.zeros((local_view_size, local_view_size))
        unit_energy_channel = np.full((local_view_size, local_view_size), unit_energy / 100.0)
        step_channel = np.full((local_view_size, local_view_size), step / 505.0)
        dist_relic_channel = np.full((local_view_size, local_view_size), 1.0)
        dist_reward_channel = np.full((local_view_size, local_view_size), 1.0)

        x_center, y_center = unit_pos
        for x_local in range(-pad_width, pad_width + 1):
            for y_local in range(-pad_width, pad_width + 1):
                x_map = (x_center + x_local) % self.map_width
                y_map = (y_center + y_local) % self.map_height
                x_view = x_local + pad_width
                y_view = y_local + pad_width

                node = self.space.get_node(x_map, y_map)
                tile_type_channel[y_view, x_view] = node.type.value / 3.0
                if node.energy is not None:
                    energy_channel[y_view, x_view] = node.energy / 100.0
                if node.relic:
                    relic_channel[y_view, x_view] = 1.0
                if node.explored_for_reward:
                    reward_channel[y_view, x_view] = 1.0 if node.reward else 0.0

                for ship in self.fleet:
                    if ship.coordinates == (x_map, y_map):
                        units_channel[y_view, x_view] = ship.energy / 100.0
                for opp_ship in self.opp_fleet:
                    if opp_ship.coordinates == (x_map, y_map):
                        units_channel[y_view, x_view] = -opp_ship.energy / 100.0

                if not node.explored_for_relic:
                    dist_relic_channel[y_view, x_view] = min(dist_relic_channel[y_view, x_view],
                        manhattan_distance((x_center, y_center), (x_map, y_map)) / (self.map_width + self.map_height))
                if node.explored_for_reward and node.reward:
                    dist_reward_channel[y_view, x_view] = min(dist_reward_channel[y_view, x_view],
                        manhattan_distance((x_center, y_center), (x_map, y_map)) / (self.map_width + self.map_height))

        state = np.stack([
            tile_type_channel,
            energy_channel,
            relic_channel,
            reward_channel,
            units_channel,
            unit_energy_channel,
            step_channel,
            dist_relic_channel,
            dist_reward_channel,
        ], axis=0)

        return torch.FloatTensor(state).to(self.device)

    def _get_action_mask(self, unit_pos):
        mask = np.ones(self.action_size)
        x, y = unit_pos
        if x == 0:
            mask[ActionType.left] = 0
        if x == self.map_width - 1:
            mask[ActionType.right] = 0
        if y == 0:
            mask[ActionType.up] = 0
        if y == self.map_height - 1:
            mask[ActionType.down] = 0
        return mask

    def act(self, step: int, obs, remainingOverageTime: int = 60):
        points = int(obs["team_points"][self.team_id])
        reward = max(0, points - self.fleet.points)
        self.space.update(step, obs, self.team_id, reward)
        self.fleet.update(obs, self.space)
        self.opp_fleet.update(obs, self.space)
        actions_array = []

        for unit_id in range(len(self.fleet.ships)):
            if self.fleet.ships[unit_id].node is None:
                actions_array.append((0, 0, 0))
                continue

            ship = self.fleet.ships[unit_id]
            unit_pos = obs["units"]["position"][self.team_id][unit_id]
            unit_energy = obs["units"]["energy"][self.team_id][unit_id]

            if self.try_sap_on_enemies(ship):
                actions_array.append(ship.action)
                continue

            state = self._state_representation(unit_pos, unit_energy, step, obs)
            action_mask = self._get_action_mask(unit_pos)
            if random.random() < self.epsilon and self.training:  # Explore
                valid_actions = np.where(action_mask == 1)[0]
                action_type = random.choice(valid_actions) if valid_actions.size > 0 else 0
            else:  # Exploit
                with torch.no_grad():
                    q_values = self.policy_net(state.unsqueeze(0))
                    invalid_mask = (1 - torch.FloatTensor(action_mask).to(self.device))
                    q_values = q_values + invalid_mask * (-1e9)
                    action_type = q_values.argmax().item()

            actions_array.append((action_type, 0, 0))
        return np.array(actions_array)

    def try_sap_on_enemies(self, ship) -> bool:
        targets = []
        for opp_ship in self.opp_fleet:
            if opp_ship.node is None:
                continue
            dist = manhattan_distance(ship.coordinates, opp_ship.coordinates)
            if dist <= self.UNIT_SAP_RANGE:
                priority = opp_ship.energy - dist
                targets.append((priority, opp_ship))
        if targets:
            targets.sort(key=lambda x: x[0], reverse=True)
            best_target_ship = targets[0][1]
            dx = best_target_ship.coordinates[0] - ship.coordinates[0]
            dy = best_target_ship.coordinates[1] - ship.coordinates[1]
            ship.action = (ActionType.sap, dx, dy)
            return True
        return False

    def learn(self, step, last_obs, actions, obs, rewards, dones):
        # If not training or if not enough samples in memory, return placeholders.
        if not self.training or len(self.memory) < self.batch_size:
            return None, None, self.epsilon, self.frame_count, None
    
        batch, indices, weights = self.memory.sample(self.batch_size)
        self.frame_count += 1
        states, actions_tensor, rewards_tensor, next_states, dones_tensor = zip(*batch)
    
        states = torch.stack(states)
        actions_tensor = torch.LongTensor(actions_tensor).to(self.device)
        rewards_tensor = torch.FloatTensor(rewards_tensor).to(self.device)
        next_states = torch.stack(next_states)
        dones_tensor = torch.FloatTensor(dones_tensor).to(self.device)
        weights = weights.view(-1, 1)
    
        # Compute current Q-values
        current_q_values = self.policy_net(states).gather(1, actions_tensor.unsqueeze(1).clamp(0, self.action_size - 1))
        
        # Compute next Q-values using target network
        next_actions = self.policy_net(next_states).argmax(1, keepdim=True)
        next_q_values = self.target_net(next_states).gather(1, next_actions).detach()
        
        # Compute target Q-values via the Bellman update.
        target_q_values = rewards_tensor + (1 - dones_tensor) * self.gamma * next_q_values
    
        # Update replay buffer priorities using the absolute TD errors.
        errors = (target_q_values - current_q_values).abs().cpu().detach().numpy()
        self.memory.update_priorities(indices, errors)
    
        # ------------------ Value Loss ------------------
        value_loss = (weights * (current_q_values - target_q_values) ** 2).mean()
    
        # ------------------ Policy (Entropy) Loss ------------------
        # Derive a policy distribution from the Q-values by applying softmax.
        q_values_all = self.policy_net(states)
        policy_dist = torch.softmax(q_values_all, dim=1)
        entropy = -(policy_dist * torch.log(policy_dist + 1e-10)).sum(dim=1).mean()
        entropy_coef = 0.001  # Hyperparameter to scale the entropy bonus
    
        loss = (weights * (current_q_values - target_q_values) ** 2).mean()
    
        # ------------------ Explained Variance ------------------
        num = torch.var(target_q_values - current_q_values)
        denom = torch.var(target_q_values) + 1e-10
        explained_variance = 1 - num / denom
    
        # ------------------ Optimization Step ------------------
        self.optimizer.zero_grad()
        loss.backward()
        for param in self.policy_net.parameters():
            if param.grad is not None:
                param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        self.scheduler.step()
    
        # Soft update the target network.
        tau = 0.005
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_(tau * policy_param.data + (1.0 - tau) * target_param.data)
    
        # Decay epsilon.
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        print(f"Loss: {loss.item():.4f}, Value Loss: {value_loss.item():.4f}, Entropy: {entropy.item():.4f}, "
              f"LR: {self.optimizer.param_groups[0]['lr']:.6f}, Epsilon: {self.epsilon:.4f}, "
              f"Frame: {self.frame_count}, Explained Variance: {explained_variance.item():.4f}")
    
        return loss.item(), self.optimizer.param_groups[0]['lr'], self.epsilon, self.frame_count, explained_variance.item()


    def save_model(self):
        torch.save({
            'policy_net': self.policy_net.state_dict(),
            'target_net': self.target_net.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'frame_count': self.frame_count,
            'epsilon': self.epsilon,
        }, f'dqn_model_{self.player}.pth')

    def load_model(self):
        try:
            checkpoint = torch.load(f'dqn_model_{self.player}.pth')
            self.policy_net.load_state_dict(checkpoint['policy_net'])
            self.target_net.load_state_dict(checkpoint['target_net'])
            self.optimizer.load_state_dict(checkpoint['optimizer'])
            self.frame_count = checkpoint.get('frame_count', 1)
            self.epsilon = checkpoint.get('epsilon', self.epsilon_start)
            self.target_net.eval()
        except FileNotFoundError:
            print(f"No trained model found for {self.player}, starting from scratch.")

class SimpleAgent:
    def __init__(self, player: str, env_cfg, training=False) -> None:
        self.player = player
        self.team_id = 0 if player == "player_0" else 1
        self.env_cfg = env_cfg

    def act(self, step: int, obs, remainingOverageTime: int = 60):
        actions = []
        for unit_id in range(self.env_cfg["max_units"]):
            if obs["units_mask"][self.team_id][unit_id]:
                valid_moves = []
                x, y = obs["units"]["position"][self.team_id][unit_id]
                if x > 0: valid_moves.append(4)  # left
                if x < self.env_cfg["map_width"] - 1: valid_moves.append(2)  # right
                if y > 0: valid_moves.append(1)  # up
                if y < self.env_cfg["map_height"] - 1: valid_moves.append(3)  # down
                valid_moves.append(0) # center
                action = random.choice(valid_moves) if valid_moves else 0
                actions.append((action, 0, 0))
            else:
                actions.append((0, 0, 0))
        return np.array(actions)

# %%
import random
import numpy as np
import torch
import wandb
from luxai_s3.wrappers import LuxAIS3GymEnv

def validate(agent_0, agent_1, env_cfg, num_validation_games=5):
    print("Validating...")
    env = LuxAIS3GymEnv(numpy_output=True)
    total_score_0 = 0
    total_score_1 = 0

    for _ in range(num_validation_games):
        seed = random.randint(0, 100000)
        obs, _ = env.reset(seed=seed)
        game_done = False
        step = 0

        while not game_done:
            actions = {}
            for agent in [agent_0, agent_1]:
                if obs[agent.player] is not None:
                    actions[agent.player] = agent.act(step=step, obs=obs[agent.player])
                else:
                    actions[agent.player] = np.zeros((env_cfg["max_units"], 3), dtype=int)
            obs, _, terminated, truncated, _ = env.step(actions)
            dones = {k: terminated[k] | truncated[k] for k in terminated}
            if dones["player_0"] or dones["player_1"]:
                game_done = True
                if obs["player_0"] is not None:
                    total_score_0 += obs["player_0"]["team_points"][agent_0.team_id]
                if obs["player_1"] is not None:
                    total_score_1 += obs["player_1"]["team_points"][agent_1.team_id]
            step += 1

    avg_score_0 = total_score_0 / num_validation_games
    avg_score_1 = total_score_1 / num_validation_games
    print(f"Validation - Avg Score Player 0: {avg_score_0}, Avg Score Player 1: {avg_score_1}")
    env.close()
    return avg_score_0, avg_score_1

def evaluate_agents(agent_1_cls, agent_2_cls, seed=42, training=True, games_to_play=3, validate_every=5):
    wandb.init(
        project="dqn_luxai_s3",
        config={
            "seed": seed,
            "games_to_play": games_to_play,
            "validate_every": validate_every,
            "batch_size": 128,
            "gamma": 0.99,
            "epsilon_start": 1.0,
            "epsilon_min": 0.05,
            "epsilon_decay": 0.9995,
            "learning_rate": 0.0001,
            "replay_buffer_capacity": 50000,
            "beta_frames": 200000,
        },
    )
    config = wandb.config

    # Seed for reproducibility.
    random.seed(config.seed)
    np.random.seed(config.seed)
    torch.manual_seed(config.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(config.seed)

    env = LuxAIS3GymEnv(numpy_output=True)
    obs, info = env.reset(seed=config.seed)
    env_cfg = info["params"]

    if training:
        player_0 = agent_1_cls("player_0", env_cfg, training=training)
        player_1 = agent_2_cls("player_1", env_cfg, training=training)
    else:
        player_0 = agent_1_cls("player_0", env_cfg, training=training)
        player_1 = agent_2_cls("player_1", env_cfg, training=training)
        player_0.load_model()
        player_1.load_model()

    for i in range(games_to_play):
        obs, info = env.reset(seed=config.seed + i)
        game_done = False
        step = 0
        last_obs = None
        last_actions = None
        episode_reward_0 = 0
        episode_reward_1 = 0

        while not game_done:
            actions = {}
            if training:
                last_obs = {
                    "player_0": obs["player_0"].copy() if obs["player_0"] is not None else None,
                    "player_1": obs["player_1"].copy() if obs["player_1"] is not None else None,
                }
            for agent in [player_0, player_1]:
                if obs[agent.player] is not None:
                    actions[agent.player] = agent.act(step=step, obs=obs[agent.player])
                else:
                    actions[agent.player] = np.zeros((env_cfg["max_units"], 3), dtype=int)

            if training:
                last_actions = actions.copy()

            obs, rewards, terminated, truncated, info = env.step(actions)
            dones = {k: terminated[k] | truncated[k] for k in terminated}

            new_rewards = {
                "player_0": obs["player_0"]["team_points"][player_0.team_id] if obs["player_0"] is not None else 0,
                "player_1": obs["player_1"]["team_points"][player_1.team_id] if obs["player_1"] is not None else 0,
            }
            if last_obs is not None:
                rewards = {
                    "player_0": new_rewards["player_0"] - (last_obs["player_0"]["team_points"][player_0.team_id] if last_obs["player_0"] is not None else 0),
                    "player_1": new_rewards["player_1"] - (last_obs["player_1"]["team_points"][player_1.team_id] if last_obs["player_1"] is not None else 0),
                }
            else:
                rewards = new_rewards

            episode_reward_0 += rewards["player_0"]
            episode_reward_1 += rewards["player_1"]

            if training and last_obs is not None:
                for agent in [player_0, player_1]:
                    for unit_id in range(env_cfg["max_units"]):
                        if last_obs[agent.player] is not None and last_obs[agent.player]["units_mask"][agent.team_id][unit_id]:
                            current_state = agent._state_representation(
                                last_obs[agent.player]["units"]["position"][agent.team_id][unit_id],
                                last_obs[agent.player]["units"]["energy"][agent.team_id][unit_id],
                                step,
                                last_obs[agent.player]
                            )
                            if obs[agent.player] is not None and obs[agent.player]["units_mask"][agent.team_id][unit_id]:
                                next_state = agent._state_representation(
                                    obs[agent.player]["units"]["position"][agent.team_id][unit_id],
                                    obs[agent.player]["units"]["energy"][agent.team_id][unit_id],
                                    step + 1,
                                    obs[agent.player]
                                )
                            else:
                                next_state = torch.zeros_like(current_state)
                            agent.memory.push(
                                current_state,
                                last_actions[agent.player][unit_id][0],
                                rewards[agent.player],
                                next_state,
                                dones[agent.player]
                            )
                loss_0 = None
                loss_1 = None
                explained_variance_0 = None
                explained_variance_1 = None
                if last_obs["player_0"] is not None:
                    loss_0, lr, eps, frame, explained_variance_0 = player_0.learn(
                        step, last_obs["player_0"], actions["player_0"],
                        obs["player_0"], rewards["player_0"], dones["player_0"]
                    )
                if last_obs["player_1"] is not None:
                    loss_1, _, _, _, explained_variance_1 = player_1.learn(
                        step, last_obs["player_1"], actions["player_1"],
                        obs["player_1"], rewards["player_1"], dones["player_1"]
                    )
                # Log training metrics to wandb.

                clipped_explained_variance_0 = explained_variance_0
                clipped_explained_variance_1 = explained_variance_1

                if clipped_explained_variance_0 is not None and clipped_explained_variance_0 < -1.0:
                    clipped_explained_variance_0 = -1.0
                if clipped_explained_variance_1 is not None and clipped_explained_variance_1 < -1.0:
                    clipped_explained_variance_1 = -1.0
                
                wandb.log({
                    "loss_player_0": loss_0,
                    "loss_player_1": loss_1,
                    "learning_rate": lr,
                    "epsilon": eps,
                    "frame": frame,
                    "step": step,
                    "explained_variance_player_0": explained_variance_0,
                    "explained_variance_player_1": explained_variance_1,
                    "clipped_explained_variance_player_0": clipped_explained_variance_0,
                    "clipped_explained_variance_player_1": clipped_explained_variance_1,
                })

            if dones["player_0"] or dones["player_1"]:
                game_done = True
                if training:
                    player_0.save_model()
                    player_1.save_model()

            step += 1

        # Log episode-level rewards.
        wandb.log({
            "episode": i,
            "episode_reward_player_0": episode_reward_0,
            "episode_reward_player_1": episode_reward_1,
        })

        if training and (i + 1) % validate_every == 0:
            player_1_validation = SimpleAgent("player_1", env_cfg, training=False)
            avg_score_0, avg_score_1 = validate(player_0, player_1_validation, env_cfg)
            wandb.log({
                "validation_avg_score_player_0": avg_score_0,
                "validation_avg_score_player_1": avg_score_1,
            })

    env.close()
    if training:
        player_0.save_model()
        player_1.save_model()
    wandb.finish()

if __name__ == "__main__":
    evaluate_agents(Agent, Agent, seed=42, training=True, games_to_play=50, validate_every=5)
# Out:
#  View run <strong style="color:#cdcd00">denim-leaf-9</strong> at: <a href='https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3/runs/vxg7lq77' target="_blank">https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3/runs/vxg7lq77</a><br> View project at: <a href='https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3' target="_blank">https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250415_004132-vxg7lq77\logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>C:\Users\maxim\OneDrive\Documents\GitHub\Project\kits\python\wandb\run-20250415_004442-6ihkku7v</code>
# Syncing run <strong><a href='https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3/runs/6ihkku7v' target="_blank">sage-jazz-10</a></strong> to <a href='https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3' target="_blank">https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3</a>
#  View run at <a href='https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3/runs/6ihkku7v' target="_blank">https://wandb.ai/ay2425s2-cs3263-group-13/dqn_luxai_s3/runs/6ihkku7v</a>
# C:\Users\maxim\AppData\Local\Temp\ipykernel_10152\2887017177.py:658: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   dones_tensor = torch.FloatTensor(dones_tensor).to(self.device)
# Loss: 0.0075, Value Loss: 0.0075, Entropy: 1.6055, LR: 0.000100, Epsilon: 0.9995, Frame: 2, Explained Variance: -32.7917
# Loss: 0.0031, Value Loss: 0.0031, Entropy: 1.6080, LR: 0.000100, Epsilon: 0.9995, Frame: 2, Explained Variance: -13.3810
# Loss: 0.0056, Value Loss: 0.0056, Entropy: 1.6085, LR: 0.000100, Epsilon: 0.9990, Frame: 3, Explained Variance: -4.1863
# Loss: 0.0038, Value Loss: 0.0038, Entropy: 1.6069, LR: 0.000100, Epsilon: 0.9990, Frame: 3, Explained Variance: -51.9660
# Loss: 0.0036, Value Loss: 0.0036, Entropy: 1.6080, LR: 0.000100, Epsilon: 0.9985, Frame: 4, Explained Variance: -36.0930
# Loss: 0.0025, Value Loss: 0.0025, Entropy: 1.6078, LR: 0.000100, Epsilon: 0.9985, Frame: 4, Explained Variance: -8.5843
# Loss: 0.0016, Value Loss: 0.0016, Entropy: 1.6084, LR: 0.000100, Epsilon: 0.9980, Frame: 5, Explained Variance: -21.8446
# Loss: 0.0015, Value Loss: 0.0015, Entropy: 1.6086, LR: 0.000100, Epsilon: 0.9980, Frame: 5, Explained Variance: -4.9357
# Loss: 0.0023, Value Loss: 0.0023, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9975, Frame: 6, Explained Variance: -3.4949
# Loss: 0.0011, Value Loss: 0.0011, Entropy: 1.6088, LR: 0.000100, Epsilon: 0.9975, Frame: 6, Explained Variance: -2.5413
# Loss: 0.0034, Value Loss: 0.0034, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9970, Frame: 7, Explained Variance: -1.4870
# Loss: 0.0025, Value Loss: 0.0025, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9970, Frame: 7, Explained Variance: -1.0427
# Loss: 0.0021, Value Loss: 0.0021, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9965, Frame: 8, Explained Variance: -2.0341
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9965, Frame: 8, Explained Variance: -4.2621
# Loss: 0.0011, Value Loss: 0.0011, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9960, Frame: 9, Explained Variance: -3.2389
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6088, LR: 0.000100, Epsilon: 0.9960, Frame: 9, Explained Variance: -9.9187
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9955, Frame: 10, Explained Variance: -2.2134
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6087, LR: 0.000100, Epsilon: 0.9955, Frame: 10, Explained Variance: -13.3204
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9950, Frame: 11, Explained Variance: -0.6472
# Loss: 0.0011, Value Loss: 0.0011, Entropy: 1.6088, LR: 0.000100, Epsilon: 0.9950, Frame: 11, Explained Variance: -13.0339
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9945, Frame: 12, Explained Variance: -0.2954
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9945, Frame: 12, Explained Variance: -5.2523
# Loss: 0.0018, Value Loss: 0.0018, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9940, Frame: 13, Explained Variance: -0.8419
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9940, Frame: 13, Explained Variance: -1.3323
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9935, Frame: 14, Explained Variance: -0.5998
# Loss: 0.0011, Value Loss: 0.0011, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9935, Frame: 14, Explained Variance: -1.4337
# Loss: 0.0010, Value Loss: 0.0010, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9930, Frame: 15, Explained Variance: -0.8150
# Loss: 0.0013, Value Loss: 0.0013, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9930, Frame: 15, Explained Variance: -3.2962
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9925, Frame: 16, Explained Variance: -0.4934
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9925, Frame: 16, Explained Variance: -4.8044
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9920, Frame: 17, Explained Variance: -0.7017
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9920, Frame: 17, Explained Variance: -8.4956
# Loss: 0.0010, Value Loss: 0.0010, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9915, Frame: 18, Explained Variance: -0.9471
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9915, Frame: 18, Explained Variance: -2.3098
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9910, Frame: 19, Explained Variance: -0.8423
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9910, Frame: 19, Explained Variance: -1.1170
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9905, Frame: 20, Explained Variance: -0.8039
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9905, Frame: 20, Explained Variance: -0.6474
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9900, Frame: 21, Explained Variance: -0.7017
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9900, Frame: 21, Explained Variance: -0.7986
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9896, Frame: 22, Explained Variance: -0.6326
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9896, Frame: 22, Explained Variance: -1.8617
# Loss: 0.0010, Value Loss: 0.0010, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9891, Frame: 23, Explained Variance: -0.3677
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9891, Frame: 23, Explained Variance: -4.8034
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9886, Frame: 24, Explained Variance: -0.2013
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9886, Frame: 24, Explained Variance: -6.7591
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9881, Frame: 25, Explained Variance: -0.1669
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9881, Frame: 25, Explained Variance: -7.8257
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9876, Frame: 26, Explained Variance: -0.3757
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9876, Frame: 26, Explained Variance: -8.2776
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9871, Frame: 27, Explained Variance: -0.8193
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9871, Frame: 27, Explained Variance: -6.3465
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9866, Frame: 28, Explained Variance: -0.7225
# Loss: 0.0004, Value Loss: 0.0004, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9866, Frame: 28, Explained Variance: -2.8903
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9861, Frame: 29, Explained Variance: -1.2521
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9861, Frame: 29, Explained Variance: -0.5510
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9856, Frame: 30, Explained Variance: -0.6035
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9856, Frame: 30, Explained Variance: -0.4608
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9851, Frame: 31, Explained Variance: -0.2585
# Loss: 0.0019, Value Loss: 0.0019, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9851, Frame: 31, Explained Variance: -0.8498
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9846, Frame: 32, Explained Variance: -0.6223
# Loss: 0.0017, Value Loss: 0.0017, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9846, Frame: 32, Explained Variance: -2.4209
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9841, Frame: 33, Explained Variance: -0.3125
# Loss: 0.0010, Value Loss: 0.0010, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9841, Frame: 33, Explained Variance: -2.4666
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9836, Frame: 34, Explained Variance: -0.5986
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9836, Frame: 34, Explained Variance: -1.9873
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9831, Frame: 35, Explained Variance: -0.6277
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9831, Frame: 35, Explained Variance: -2.4092
# Loss: 0.0010, Value Loss: 0.0010, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9826, Frame: 36, Explained Variance: -0.3641
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9826, Frame: 36, Explained Variance: -2.1915
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9822, Frame: 37, Explained Variance: -0.4964
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9822, Frame: 37, Explained Variance: -1.9640
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9817, Frame: 38, Explained Variance: -0.2254
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9817, Frame: 38, Explained Variance: -1.0170
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9812, Frame: 39, Explained Variance: -0.6203
# Loss: 0.0011, Value Loss: 0.0011, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9812, Frame: 39, Explained Variance: -0.9073
# Loss: 0.0421, Value Loss: 0.0421, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9807, Frame: 40, Explained Variance: -0.0089
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9807, Frame: 40, Explained Variance: -0.5328
# Loss: 0.0264, Value Loss: 0.0264, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9802, Frame: 41, Explained Variance: -0.0082
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9802, Frame: 41, Explained Variance: -0.1192
# Loss: 0.0193, Value Loss: 0.0193, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9797, Frame: 42, Explained Variance: -0.0188
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9797, Frame: 42, Explained Variance: -1.7043
# Loss: 0.0325, Value Loss: 0.0325, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9792, Frame: 43, Explained Variance: -0.0088
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9792, Frame: 43, Explained Variance: -4.4196
# Loss: 0.0579, Value Loss: 0.0579, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9787, Frame: 44, Explained Variance: -0.0032
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9787, Frame: 44, Explained Variance: -5.9427
# Loss: 0.0621, Value Loss: 0.0621, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9782, Frame: 45, Explained Variance: -0.0018
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9782, Frame: 45, Explained Variance: -5.0322
# Loss: 0.0287, Value Loss: 0.0287, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9777, Frame: 46, Explained Variance: -0.0043
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9777, Frame: 46, Explained Variance: -4.9323
# Loss: 0.0670, Value Loss: 0.0670, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9773, Frame: 47, Explained Variance: -0.0019
# Loss: 0.0004, Value Loss: 0.0004, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9773, Frame: 47, Explained Variance: -5.6797
# Loss: 0.0447, Value Loss: 0.0447, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9768, Frame: 48, Explained Variance: -0.0037
# Loss: 0.0004, Value Loss: 0.0004, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9768, Frame: 48, Explained Variance: -3.5980
# Loss: 0.0549, Value Loss: 0.0549, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9763, Frame: 49, Explained Variance: -0.0034
# Loss: 0.0004, Value Loss: 0.0004, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9763, Frame: 49, Explained Variance: -2.3503
# Loss: 0.0336, Value Loss: 0.0336, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9758, Frame: 50, Explained Variance: -0.0065
# Loss: 0.0004, Value Loss: 0.0004, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9758, Frame: 50, Explained Variance: -0.7904
# Loss: 0.0208, Value Loss: 0.0208, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9753, Frame: 51, Explained Variance: -0.0044
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9753, Frame: 51, Explained Variance: -0.3162
# Loss: 0.0486, Value Loss: 0.0486, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9748, Frame: 52, Explained Variance: -0.0043
# Loss: 0.0010, Value Loss: 0.0010, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9748, Frame: 52, Explained Variance: 0.0251
# Loss: 0.0764, Value Loss: 0.0764, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9743, Frame: 53, Explained Variance: -0.0024
# Loss: 0.0013, Value Loss: 0.0013, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9743, Frame: 53, Explained Variance: -0.1483
# Loss: 0.0271, Value Loss: 0.0271, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9738, Frame: 54, Explained Variance: -0.0041
# Loss: 0.0013, Value Loss: 0.0013, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9738, Frame: 54, Explained Variance: -0.2619
# Loss: 0.0485, Value Loss: 0.0485, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9734, Frame: 55, Explained Variance: -0.0005
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9734, Frame: 55, Explained Variance: -0.5009
# Loss: 0.0671, Value Loss: 0.0671, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9729, Frame: 56, Explained Variance: -0.0024
# Loss: 0.0009, Value Loss: 0.0009, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9729, Frame: 56, Explained Variance: -1.1534
# Loss: 0.0822, Value Loss: 0.0822, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9724, Frame: 57, Explained Variance: -0.0009
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9724, Frame: 57, Explained Variance: -1.3040
# Loss: 0.0861, Value Loss: 0.0861, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9719, Frame: 58, Explained Variance: -0.0019
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9719, Frame: 58, Explained Variance: -1.2208
# Loss: 0.0625, Value Loss: 0.0625, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9714, Frame: 59, Explained Variance: -0.0020
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9714, Frame: 59, Explained Variance: -1.3360
# Loss: 0.0773, Value Loss: 0.0773, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9709, Frame: 60, Explained Variance: -0.0011
# Loss: 0.0003, Value Loss: 0.0003, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9709, Frame: 60, Explained Variance: -0.9662
# Loss: 0.0701, Value Loss: 0.0701, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9704, Frame: 61, Explained Variance: -0.0017
# Loss: 0.0004, Value Loss: 0.0004, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9704, Frame: 61, Explained Variance: -0.5012
# Loss: 0.1062, Value Loss: 0.1062, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9700, Frame: 62, Explained Variance: -0.0012
# Loss: 0.0007, Value Loss: 0.0007, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9700, Frame: 62, Explained Variance: -0.2161
# Loss: 0.0878, Value Loss: 0.0878, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9695, Frame: 63, Explained Variance: -0.0025
# Loss: 0.0011, Value Loss: 0.0011, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9695, Frame: 63, Explained Variance: -0.0978
# Loss: 0.0815, Value Loss: 0.0815, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9690, Frame: 64, Explained Variance: -0.0044
# Loss: 0.0015, Value Loss: 0.0015, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9690, Frame: 64, Explained Variance: -0.3404
# Loss: 0.1102, Value Loss: 0.1102, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9685, Frame: 65, Explained Variance: -0.0025
# Loss: 0.0018, Value Loss: 0.0018, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9685, Frame: 65, Explained Variance: -0.5559
# Loss: 0.0938, Value Loss: 0.0938, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9680, Frame: 66, Explained Variance: -0.0016
# Loss: 0.0012, Value Loss: 0.0012, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9680, Frame: 66, Explained Variance: -1.5895
# Loss: 0.0772, Value Loss: 0.0772, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9675, Frame: 67, Explained Variance: -0.0022
# Loss: 0.0008, Value Loss: 0.0008, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9675, Frame: 67, Explained Variance: -2.7148
# Loss: 0.1952, Value Loss: 0.1952, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9670, Frame: 68, Explained Variance: -0.0023
# Loss: 0.0167, Value Loss: 0.0167, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9670, Frame: 68, Explained Variance: -0.0104
# Loss: 0.0945, Value Loss: 0.0945, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9666, Frame: 69, Explained Variance: -0.0013
# Loss: 0.0144, Value Loss: 0.0144, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9666, Frame: 69, Explained Variance: -0.0185
# Loss: 0.2512, Value Loss: 0.2512, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9661, Frame: 70, Explained Variance: -0.0009
# Loss: 0.0180, Value Loss: 0.0180, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9661, Frame: 70, Explained Variance: -0.0122
# Loss: 0.1398, Value Loss: 0.1398, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9656, Frame: 71, Explained Variance: -0.0016
# Loss: 0.0112, Value Loss: 0.0112, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9656, Frame: 71, Explained Variance: -0.0220
# Loss: 0.0702, Value Loss: 0.0702, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9651, Frame: 72, Explained Variance: -0.0031
# Loss: 0.0174, Value Loss: 0.0174, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9651, Frame: 72, Explained Variance: -0.0187
# Loss: 0.1069, Value Loss: 0.1069, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9646, Frame: 73, Explained Variance: -0.0039
# Loss: 0.0151, Value Loss: 0.0151, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9646, Frame: 73, Explained Variance: -0.0146
# Loss: 0.1066, Value Loss: 0.1066, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9641, Frame: 74, Explained Variance: -0.0034
# Loss: 0.0147, Value Loss: 0.0147, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9641, Frame: 74, Explained Variance: -0.0134
# Loss: 2.7107, Value Loss: 2.7107, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9637, Frame: 75, Explained Variance: -0.0001
# Loss: 0.0394, Value Loss: 0.0394, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9637, Frame: 75, Explained Variance: -0.0038
# Loss: 2.5405, Value Loss: 2.5405, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9632, Frame: 76, Explained Variance: -0.0001
# Loss: 0.0203, Value Loss: 0.0203, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9632, Frame: 76, Explained Variance: -0.0187
# Loss: 10.0225, Value Loss: 10.0225, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9627, Frame: 77, Explained Variance: -0.0000
# Loss: 0.0246, Value Loss: 0.0246, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9627, Frame: 77, Explained Variance: -0.0129
# Loss: 11.4013, Value Loss: 11.4013, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9622, Frame: 78, Explained Variance: -0.0001
# Loss: 0.0218, Value Loss: 0.0218, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9622, Frame: 78, Explained Variance: -0.0090
# Loss: 0.0882, Value Loss: 0.0882, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9617, Frame: 79, Explained Variance: -0.0051
# Loss: 0.0133, Value Loss: 0.0133, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9617, Frame: 79, Explained Variance: -0.0109
# Loss: 3.5403, Value Loss: 3.5403, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9613, Frame: 80, Explained Variance: -0.0001
# Loss: 0.0145, Value Loss: 0.0145, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9613, Frame: 80, Explained Variance: -0.0100
# Loss: 1.4151, Value Loss: 1.4151, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9608, Frame: 81, Explained Variance: -0.0003
# Loss: 0.0275, Value Loss: 0.0275, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9608, Frame: 81, Explained Variance: -0.0080
# Loss: 1.8910, Value Loss: 1.8910, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9603, Frame: 82, Explained Variance: -0.0002
# Loss: 0.0208, Value Loss: 0.0208, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9603, Frame: 82, Explained Variance: -0.0074
# Loss: 3.7008, Value Loss: 3.7008, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9598, Frame: 83, Explained Variance: -0.0001
# Loss: 0.0045, Value Loss: 0.0045, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9598, Frame: 83, Explained Variance: -0.0618
# Loss: 14.3896, Value Loss: 14.3896, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9593, Frame: 84, Explained Variance: -0.0000
# Loss: 0.0135, Value Loss: 0.0135, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9593, Frame: 84, Explained Variance: -0.0134
# Loss: 10.3599, Value Loss: 10.3599, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9589, Frame: 85, Explained Variance: -0.0000
# Loss: 0.0093, Value Loss: 0.0093, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9589, Frame: 85, Explained Variance: -0.0167
# Loss: 9.7182, Value Loss: 9.7182, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9584, Frame: 86, Explained Variance: -0.0001
# Loss: 0.0045, Value Loss: 0.0045, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9584, Frame: 86, Explained Variance: -0.0567
# Loss: 3.3949, Value Loss: 3.3949, Entropy: 1.6088, LR: 0.000100, Epsilon: 0.9579, Frame: 87, Explained Variance: -0.0004
# Loss: 0.0166, Value Loss: 0.0166, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9579, Frame: 87, Explained Variance: -0.0071
# Loss: 5.6531, Value Loss: 5.6531, Entropy: 1.6087, LR: 0.000100, Epsilon: 0.9574, Frame: 88, Explained Variance: -0.0001
# Loss: 0.0174, Value Loss: 0.0174, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9574, Frame: 88, Explained Variance: -0.0073
# Loss: 6.5803, Value Loss: 6.5803, Entropy: 1.6088, LR: 0.000100, Epsilon: 0.9569, Frame: 89, Explained Variance: -0.0001
# Loss: 0.0037, Value Loss: 0.0037, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9569, Frame: 89, Explained Variance: -0.0304
# Loss: 0.2229, Value Loss: 0.2229, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9565, Frame: 90, Explained Variance: -0.0047
# Loss: 0.0208, Value Loss: 0.0208, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9565, Frame: 90, Explained Variance: -0.0039
# Loss: 0.1004, Value Loss: 0.1004, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9560, Frame: 91, Explained Variance: -0.0033
# Loss: 0.0119, Value Loss: 0.0119, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9560, Frame: 91, Explained Variance: -0.0014
# Loss: 1.8008, Value Loss: 1.8008, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9555, Frame: 92, Explained Variance: -0.0001
# Loss: 0.0151, Value Loss: 0.0151, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9555, Frame: 92, Explained Variance: 0.0020
# Loss: 6.1485, Value Loss: 6.1485, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9550, Frame: 93, Explained Variance: -0.0001
# Loss: 0.0197, Value Loss: 0.0197, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9550, Frame: 93, Explained Variance: -0.0004
# Loss: 6.8260, Value Loss: 6.8260, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9546, Frame: 94, Explained Variance: -0.0001
# Loss: 0.0185, Value Loss: 0.0185, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9546, Frame: 94, Explained Variance: -0.0034
# Loss: 6.6577, Value Loss: 6.6577, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9541, Frame: 95, Explained Variance: -0.0001
# Loss: 0.0169, Value Loss: 0.0169, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9541, Frame: 95, Explained Variance: -0.0059
# Loss: 3.5614, Value Loss: 3.5614, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9536, Frame: 96, Explained Variance: -0.0001
# Loss: 0.0097, Value Loss: 0.0097, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9536, Frame: 96, Explained Variance: -0.0095
# Loss: 3.3267, Value Loss: 3.3267, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9531, Frame: 97, Explained Variance: -0.0001
# Loss: 0.0087, Value Loss: 0.0087, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9531, Frame: 97, Explained Variance: -0.0173
# Loss: 6.5589, Value Loss: 6.5589, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9526, Frame: 98, Explained Variance: -0.0000
# Loss: 0.0071, Value Loss: 0.0071, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9526, Frame: 98, Explained Variance: -0.0161
# Loss: 0.0961, Value Loss: 0.0961, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9522, Frame: 99, Explained Variance: -0.0024
# Loss: 0.0180, Value Loss: 0.0180, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9522, Frame: 99, Explained Variance: -0.0078
# Loss: 1.9391, Value Loss: 1.9391, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9517, Frame: 100, Explained Variance: -0.0001
# Loss: 0.0068, Value Loss: 0.0068, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9517, Frame: 100, Explained Variance: -0.0232
# Loss: 1.6690, Value Loss: 1.6690, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9512, Frame: 101, Explained Variance: -0.0001
# Loss: 0.0135, Value Loss: 0.0135, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9512, Frame: 101, Explained Variance: -0.0094
# Loss: 0.2025, Value Loss: 0.2025, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9507, Frame: 102, Explained Variance: -0.0029
# Loss: 0.0069, Value Loss: 0.0069, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9507, Frame: 102, Explained Variance: -0.0116
# Loss: 0.0937, Value Loss: 0.0937, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9503, Frame: 103, Explained Variance: -0.0058
# Loss: 0.0030, Value Loss: 0.0030, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9503, Frame: 103, Explained Variance: -0.0255
# Loss: 7.1216, Value Loss: 7.1216, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9498, Frame: 104, Explained Variance: -0.0002
# Loss: 0.0150, Value Loss: 0.0150, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9498, Frame: 104, Explained Variance: -0.0038
# Loss: 3.4255, Value Loss: 3.4255, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9493, Frame: 105, Explained Variance: -0.0002
# Loss: 0.0056, Value Loss: 0.0056, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9493, Frame: 105, Explained Variance: -0.0063
# Loss: 7.4314, Value Loss: 7.4314, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9488, Frame: 106, Explained Variance: -0.0000
# Loss: 0.0177, Value Loss: 0.0177, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9488, Frame: 106, Explained Variance: -0.0043
# Loss: 3.7712, Value Loss: 3.7712, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9484, Frame: 107, Explained Variance: -0.0000
# Loss: 0.0170, Value Loss: 0.0170, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9484, Frame: 107, Explained Variance: -0.0008
# Loss: 4.7146, Value Loss: 4.7146, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9479, Frame: 108, Explained Variance: -0.0000
# Loss: 0.0057, Value Loss: 0.0057, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9479, Frame: 108, Explained Variance: -0.0073
# Loss: 0.0909, Value Loss: 0.0909, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9474, Frame: 109, Explained Variance: -0.0017
# Loss: 0.0106, Value Loss: 0.0106, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9474, Frame: 109, Explained Variance: -0.0028
# Loss: 3.3386, Value Loss: 3.3386, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9469, Frame: 110, Explained Variance: -0.0001
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9469, Frame: 110, Explained Variance: -0.7554
# Loss: 5.0045, Value Loss: 5.0045, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9465, Frame: 111, Explained Variance: -0.0000
# Loss: 0.0195, Value Loss: 0.0195, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9465, Frame: 111, Explained Variance: -0.0039
# Loss: 12.6535, Value Loss: 12.6535, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9460, Frame: 112, Explained Variance: -0.0000
# Loss: 0.0160, Value Loss: 0.0160, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9460, Frame: 112, Explained Variance: -0.0043
# Loss: 3.4200, Value Loss: 3.4200, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9455, Frame: 113, Explained Variance: -0.0001
# Loss: 0.0179, Value Loss: 0.0179, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9455, Frame: 113, Explained Variance: -0.0061
# Loss: 6.5987, Value Loss: 6.5987, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9451, Frame: 114, Explained Variance: -0.0001
# Loss: 0.0093, Value Loss: 0.0093, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9451, Frame: 114, Explained Variance: -0.0055
# Loss: 3.1229, Value Loss: 3.1229, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9446, Frame: 115, Explained Variance: -0.0000
# Loss: 0.0158, Value Loss: 0.0158, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9446, Frame: 115, Explained Variance: -0.0028
# Loss: 9.5812, Value Loss: 9.5812, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9441, Frame: 116, Explained Variance: -0.0001
# Loss: 0.0028, Value Loss: 0.0028, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9441, Frame: 116, Explained Variance: -0.0134
# Loss: 6.3942, Value Loss: 6.3942, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9436, Frame: 117, Explained Variance: -0.0001
# Loss: 0.0085, Value Loss: 0.0085, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9436, Frame: 117, Explained Variance: -0.0058
# Loss: 6.3256, Value Loss: 6.3256, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9432, Frame: 118, Explained Variance: -0.0001
# Loss: 0.0173, Value Loss: 0.0173, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9432, Frame: 118, Explained Variance: -0.0014
# Loss: 1.0314, Value Loss: 1.0314, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9427, Frame: 119, Explained Variance: -0.0001
# Loss: 0.0157, Value Loss: 0.0157, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9427, Frame: 119, Explained Variance: -0.0006
# Loss: 0.2542, Value Loss: 0.2542, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9422, Frame: 120, Explained Variance: -0.0035
# Loss: 0.0129, Value Loss: 0.0129, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9422, Frame: 120, Explained Variance: 0.0013
# Loss: 1.6602, Value Loss: 1.6602, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9418, Frame: 121, Explained Variance: -0.0001
# Loss: 0.0151, Value Loss: 0.0151, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9418, Frame: 121, Explained Variance: 0.0006
# Loss: 3.3466, Value Loss: 3.3466, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9413, Frame: 122, Explained Variance: -0.0001
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9413, Frame: 122, Explained Variance: -0.0440
# Loss: 8.9611, Value Loss: 8.9611, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9408, Frame: 123, Explained Variance: -0.0000
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9408, Frame: 123, Explained Variance: -0.1372
# Loss: 6.6742, Value Loss: 6.6742, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9403, Frame: 124, Explained Variance: -0.0000
# Loss: 0.0039, Value Loss: 0.0039, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9403, Frame: 124, Explained Variance: -0.0086
# Loss: 3.3581, Value Loss: 3.3581, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9399, Frame: 125, Explained Variance: -0.0001
# Loss: 0.0129, Value Loss: 0.0129, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9399, Frame: 125, Explained Variance: -0.0023
# Loss: 0.2207, Value Loss: 0.2207, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9394, Frame: 126, Explained Variance: -0.0028
# Loss: 0.0036, Value Loss: 0.0036, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9394, Frame: 126, Explained Variance: -0.0064
# Loss: 9.4843, Value Loss: 9.4843, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9389, Frame: 127, Explained Variance: -0.0000
# Loss: 0.0190, Value Loss: 0.0190, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9389, Frame: 127, Explained Variance: -0.0030
# Loss: 1.2186, Value Loss: 1.2186, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9385, Frame: 128, Explained Variance: -0.0001
# Loss: 0.0085, Value Loss: 0.0085, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9385, Frame: 128, Explained Variance: -0.0067
# Loss: 1.7323, Value Loss: 1.7323, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9380, Frame: 129, Explained Variance: -0.0001
# Loss: 0.0077, Value Loss: 0.0077, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9380, Frame: 129, Explained Variance: -0.0095
# Loss: 2.9958, Value Loss: 2.9958, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9375, Frame: 130, Explained Variance: -0.0000
# Loss: 0.0074, Value Loss: 0.0074, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9375, Frame: 130, Explained Variance: -0.0139
# Loss: 5.8173, Value Loss: 5.8173, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9371, Frame: 131, Explained Variance: -0.0000
# Loss: 0.0035, Value Loss: 0.0035, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9371, Frame: 131, Explained Variance: -0.0300
# Loss: 4.3502, Value Loss: 4.3502, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9366, Frame: 132, Explained Variance: -0.0001
# Loss: 0.0106, Value Loss: 0.0106, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9366, Frame: 132, Explained Variance: -0.0104
# Loss: 9.4902, Value Loss: 9.4902, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9361, Frame: 133, Explained Variance: -0.0000
# Loss: 0.0084, Value Loss: 0.0084, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9361, Frame: 133, Explained Variance: -0.0108
# Loss: 3.4072, Value Loss: 3.4072, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9356, Frame: 134, Explained Variance: -0.0001
# Loss: 0.0091, Value Loss: 0.0091, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9356, Frame: 134, Explained Variance: -0.0116
# Loss: 3.3917, Value Loss: 3.3917, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9352, Frame: 135, Explained Variance: -0.0000
# Loss: 0.0124, Value Loss: 0.0124, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9352, Frame: 135, Explained Variance: -0.0065
# Loss: 3.1136, Value Loss: 3.1136, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9347, Frame: 136, Explained Variance: -0.0000
# Loss: 0.0140, Value Loss: 0.0140, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9347, Frame: 136, Explained Variance: -0.0052
# Loss: 3.2251, Value Loss: 3.2251, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9342, Frame: 137, Explained Variance: -0.0000
# Loss: 0.0159, Value Loss: 0.0159, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9342, Frame: 137, Explained Variance: -0.0026
# Loss: 3.2247, Value Loss: 3.2247, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9338, Frame: 138, Explained Variance: -0.0000
# Loss: 0.0058, Value Loss: 0.0058, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9338, Frame: 138, Explained Variance: -0.0021
# Loss: 3.3120, Value Loss: 3.3120, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9333, Frame: 139, Explained Variance: -0.0000
# Loss: 0.0145, Value Loss: 0.0145, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9333, Frame: 139, Explained Variance: 0.0004
# Loss: 6.4131, Value Loss: 6.4131, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9328, Frame: 140, Explained Variance: -0.0000
# Loss: 0.0090, Value Loss: 0.0090, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9328, Frame: 140, Explained Variance: -0.0046
# Loss: 2.2750, Value Loss: 2.2750, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9324, Frame: 141, Explained Variance: -0.0000
# Loss: 0.0045, Value Loss: 0.0045, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9324, Frame: 141, Explained Variance: -0.0045
# Loss: 4.8641, Value Loss: 4.8641, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9319, Frame: 142, Explained Variance: -0.0000
# Loss: 0.0055, Value Loss: 0.0055, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9319, Frame: 142, Explained Variance: -0.0078
# Loss: 0.1967, Value Loss: 0.1967, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9314, Frame: 143, Explained Variance: -0.0009
# Loss: 0.0096, Value Loss: 0.0096, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9314, Frame: 143, Explained Variance: -0.0033
# Loss: 0.2109, Value Loss: 0.2109, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9310, Frame: 144, Explained Variance: -0.0010
# Loss: 0.0116, Value Loss: 0.0116, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9310, Frame: 144, Explained Variance: -0.0027
# Loss: 9.7122, Value Loss: 9.7122, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9305, Frame: 145, Explained Variance: -0.0000
# Loss: 0.0214, Value Loss: 0.0214, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9305, Frame: 145, Explained Variance: -0.0026
# Loss: 6.2430, Value Loss: 6.2430, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9300, Frame: 146, Explained Variance: -0.0000
# Loss: 0.0092, Value Loss: 0.0092, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9300, Frame: 146, Explained Variance: -0.0054
# Loss: 3.2748, Value Loss: 3.2748, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9296, Frame: 147, Explained Variance: -0.0001
# Loss: 0.0156, Value Loss: 0.0156, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9296, Frame: 147, Explained Variance: -0.0016
# Loss: 2.2163, Value Loss: 2.2163, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9291, Frame: 148, Explained Variance: -0.0001
# Loss: 0.0006, Value Loss: 0.0006, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9291, Frame: 148, Explained Variance: -0.6672
# Loss: 6.4428, Value Loss: 6.4428, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9287, Frame: 149, Explained Variance: -0.0000
# Loss: 0.0064, Value Loss: 0.0064, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9287, Frame: 149, Explained Variance: -0.0060
# Loss: 3.2179, Value Loss: 3.2179, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9282, Frame: 150, Explained Variance: -0.0001
# Loss: 0.0039, Value Loss: 0.0039, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9282, Frame: 150, Explained Variance: -0.0139
# Loss: 3.4091, Value Loss: 3.4091, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9277, Frame: 151, Explained Variance: -0.0001
# Loss: 0.0108, Value Loss: 0.0108, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9277, Frame: 151, Explained Variance: -0.0047
# Loss: 0.1916, Value Loss: 0.1916, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9273, Frame: 152, Explained Variance: -0.0020
# Loss: 0.0039, Value Loss: 0.0039, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9273, Frame: 152, Explained Variance: -0.0109
# Loss: 3.2655, Value Loss: 3.2655, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9268, Frame: 153, Explained Variance: -0.0001
# Loss: 0.0092, Value Loss: 0.0092, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9268, Frame: 153, Explained Variance: -0.0066
# Loss: 9.5288, Value Loss: 9.5288, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9263, Frame: 154, Explained Variance: -0.0000
# Loss: 0.0075, Value Loss: 0.0075, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9263, Frame: 154, Explained Variance: -0.0098
# Loss: 3.1629, Value Loss: 3.1629, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9259, Frame: 155, Explained Variance: -0.0001
# Loss: 0.0144, Value Loss: 0.0144, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9259, Frame: 155, Explained Variance: -0.0057
# Loss: 12.5117, Value Loss: 12.5117, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9254, Frame: 156, Explained Variance: -0.0000
# Loss: 0.0038, Value Loss: 0.0038, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9254, Frame: 156, Explained Variance: -0.0298
# Loss: 0.1551, Value Loss: 0.1551, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9249, Frame: 157, Explained Variance: -0.0021
# Loss: 0.0047, Value Loss: 0.0047, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9249, Frame: 157, Explained Variance: -0.0167
# Loss: 0.1731, Value Loss: 0.1731, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9245, Frame: 158, Explained Variance: -0.0020
# Loss: 0.0183, Value Loss: 0.0183, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9245, Frame: 158, Explained Variance: -0.0022
# Loss: 9.6704, Value Loss: 9.6704, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9240, Frame: 159, Explained Variance: -0.0000
# Loss: 0.0071, Value Loss: 0.0071, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9240, Frame: 159, Explained Variance: 0.0027
# Loss: 6.7906, Value Loss: 6.7906, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9236, Frame: 160, Explained Variance: -0.0000
# Loss: 0.0172, Value Loss: 0.0172, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9236, Frame: 160, Explained Variance: -0.0002
# Loss: 3.5420, Value Loss: 3.5420, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9231, Frame: 161, Explained Variance: -0.0000
# Loss: 0.0118, Value Loss: 0.0118, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9231, Frame: 161, Explained Variance: -0.0045
# Loss: 3.3336, Value Loss: 3.3336, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9226, Frame: 162, Explained Variance: -0.0000
# Loss: 0.0170, Value Loss: 0.0170, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9226, Frame: 162, Explained Variance: -0.0069
# Loss: 6.5795, Value Loss: 6.5795, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9222, Frame: 163, Explained Variance: -0.0000
# Loss: 0.0088, Value Loss: 0.0088, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9222, Frame: 163, Explained Variance: -0.0184
# Loss: 0.1942, Value Loss: 0.1942, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9217, Frame: 164, Explained Variance: -0.0005
# Loss: 0.0100, Value Loss: 0.0100, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9217, Frame: 164, Explained Variance: -0.0182
# Loss: 13.5429, Value Loss: 13.5429, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9213, Frame: 165, Explained Variance: -0.0000
# Loss: 0.0026, Value Loss: 0.0026, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9213, Frame: 165, Explained Variance: -0.0367
# Loss: 0.2308, Value Loss: 0.2308, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9208, Frame: 166, Explained Variance: -0.0001
# Loss: 0.0117, Value Loss: 0.0117, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9208, Frame: 166, Explained Variance: -0.0075
# Loss: 6.4876, Value Loss: 6.4876, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9203, Frame: 167, Explained Variance: -0.0000
# Loss: 0.0003, Value Loss: 0.0003, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9203, Frame: 167, Explained Variance: -5.5570
# Loss: 0.2744, Value Loss: 0.2744, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9199, Frame: 168, Explained Variance: -0.0025
# Loss: 0.0086, Value Loss: 0.0086, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9199, Frame: 168, Explained Variance: -0.0173
# Loss: 3.6521, Value Loss: 3.6521, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9194, Frame: 169, Explained Variance: -0.0001
# Loss: 0.0079, Value Loss: 0.0079, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9194, Frame: 169, Explained Variance: -0.0160
# Loss: 7.1592, Value Loss: 7.1592, Entropy: 1.6093, LR: 0.000100, Epsilon: 0.9190, Frame: 170, Explained Variance: -0.0001
# Loss: 0.0085, Value Loss: 0.0085, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9190, Frame: 170, Explained Variance: -0.0145
# Loss: 0.2989, Value Loss: 0.2989, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9185, Frame: 171, Explained Variance: -0.0017
# Loss: 0.0038, Value Loss: 0.0038, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9185, Frame: 171, Explained Variance: -0.0308
# Loss: 0.1523, Value Loss: 0.1523, Entropy: 1.6092, LR: 0.000100, Epsilon: 0.9180, Frame: 172, Explained Variance: -0.0025
# Loss: 0.0002, Value Loss: 0.0002, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9180, Frame: 172, Explained Variance: -1.8283
# Loss: 0.3094, Value Loss: 0.3094, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9176, Frame: 173, Explained Variance: -0.0038
# Loss: 0.0002, Value Loss: 0.0002, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9176, Frame: 173, Explained Variance: -1.5510
# Loss: 0.2697, Value Loss: 0.2697, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9171, Frame: 174, Explained Variance: -0.0039
# Loss: 0.0125, Value Loss: 0.0125, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9171, Frame: 174, Explained Variance: -0.0043
# Loss: 10.6072, Value Loss: 10.6072, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9167, Frame: 175, Explained Variance: -0.0001
# Loss: 0.0045, Value Loss: 0.0045, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9167, Frame: 175, Explained Variance: -0.0095
# Loss: 22.4639, Value Loss: 22.4639, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9162, Frame: 176, Explained Variance: -0.0001
# Loss: 0.0040, Value Loss: 0.0040, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9162, Frame: 176, Explained Variance: -0.0055
# Loss: 23.4004, Value Loss: 23.4004, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9157, Frame: 177, Explained Variance: -0.0001
# Loss: 0.0228, Value Loss: 0.0228, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9157, Frame: 177, Explained Variance: -0.0007
# Loss: 3.5086, Value Loss: 3.5086, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9153, Frame: 178, Explained Variance: -0.0003
# Loss: 0.0081, Value Loss: 0.0081, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9153, Frame: 178, Explained Variance: -0.0008
# Loss: 3.6501, Value Loss: 3.6501, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9148, Frame: 179, Explained Variance: -0.0003
# Loss: 0.0089, Value Loss: 0.0089, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9148, Frame: 179, Explained Variance: 0.0026
# Loss: 7.1053, Value Loss: 7.1053, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9144, Frame: 180, Explained Variance: -0.0001
# Loss: 0.0038, Value Loss: 0.0038, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9144, Frame: 180, Explained Variance: 0.0150
# Loss: 10.5844, Value Loss: 10.5844, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9139, Frame: 181, Explained Variance: -0.0000
# Loss: 0.0042, Value Loss: 0.0042, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9139, Frame: 181, Explained Variance: 0.0090
# Loss: 0.3147, Value Loss: 0.3147, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9135, Frame: 182, Explained Variance: -0.0035
# Loss: 0.0104, Value Loss: 0.0104, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9135, Frame: 182, Explained Variance: 0.0015
# Loss: 18.7492, Value Loss: 18.7492, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9130, Frame: 183, Explained Variance: -0.0000
# Loss: 0.0005, Value Loss: 0.0005, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9130, Frame: 183, Explained Variance: -0.1965
# Loss: 10.1221, Value Loss: 10.1221, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9125, Frame: 184, Explained Variance: -0.0001
# Loss: 0.0195, Value Loss: 0.0195, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9125, Frame: 184, Explained Variance: -0.0040
# Loss: 5.5170, Value Loss: 5.5170, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9121, Frame: 185, Explained Variance: -0.0000
# Loss: 0.0123, Value Loss: 0.0123, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9121, Frame: 185, Explained Variance: -0.0035
# Loss: 3.5636, Value Loss: 3.5636, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9116, Frame: 186, Explained Variance: -0.0002
# Loss: 0.0046, Value Loss: 0.0046, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9116, Frame: 186, Explained Variance: -0.0124
# Loss: 3.5634, Value Loss: 3.5634, Entropy: 1.6089, LR: 0.000100, Epsilon: 0.9112, Frame: 187, Explained Variance: -0.0002
# Loss: 0.0085, Value Loss: 0.0085, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9112, Frame: 187, Explained Variance: -0.0031
# Loss: 0.2719, Value Loss: 0.2719, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9107, Frame: 188, Explained Variance: -0.0038
# Loss: 0.0175, Value Loss: 0.0175, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9107, Frame: 188, Explained Variance: -0.0010
# Loss: 7.6296, Value Loss: 7.6296, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9103, Frame: 189, Explained Variance: -0.0001
# Loss: 0.0199, Value Loss: 0.0199, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9103, Frame: 189, Explained Variance: -0.0001
# Loss: 27.2801, Value Loss: 27.2801, Entropy: 1.6090, LR: 0.000100, Epsilon: 0.9098, Frame: 190, Explained Variance: -0.0000
# Loss: 0.0086, Value Loss: 0.0086, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9098, Frame: 190, Explained Variance: -0.0015
# Loss: 14.3730, Value Loss: 14.3730, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9094, Frame: 191, Explained Variance: -0.0000
# Loss: 0.0036, Value Loss: 0.0036, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.9094, Frame: 191, Explained Variance: 0.0001
# Loss: 0.2403, Value Loss: 0.2403, Entropy: 1.6091, LR: 0.000100, Epsilon: 0.9089, Frame: 192, Explained Variance: -0.0032
# ...
# Loss: 1.2365, Value Loss: 1.2365, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2561, Frame: 2725, Explained Variance: -0.0000
# Loss: 0.2477, Value Loss: 0.2477, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2559, Frame: 2726, Explained Variance: 0.0005
# Loss: 0.0714, Value Loss: 0.0714, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2559, Frame: 2726, Explained Variance: -0.0001
# Loss: 0.1116, Value Loss: 0.1116, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2558, Frame: 2727, Explained Variance: 0.0018
# Loss: 0.1344, Value Loss: 0.1344, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2558, Frame: 2727, Explained Variance: -0.0000
# Loss: 0.0673, Value Loss: 0.0673, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2557, Frame: 2728, Explained Variance: 0.0042
# Loss: 0.0198, Value Loss: 0.0198, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2557, Frame: 2728, Explained Variance: -0.0002
# Loss: 0.0075, Value Loss: 0.0075, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2555, Frame: 2729, Explained Variance: 0.0383
# Loss: 0.0197, Value Loss: 0.0197, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2555, Frame: 2729, Explained Variance: -0.0000
# Loss: 3.0883, Value Loss: 3.0883, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2554, Frame: 2730, Explained Variance: 0.0001
# Loss: 1.1890, Value Loss: 1.1890, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2554, Frame: 2730, Explained Variance: -0.0000
# Loss: 2.9824, Value Loss: 2.9824, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2553, Frame: 2731, Explained Variance: 0.0001
# Loss: 0.0388, Value Loss: 0.0388, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2553, Frame: 2731, Explained Variance: -0.0001
# Loss: 0.0345, Value Loss: 0.0345, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2552, Frame: 2732, Explained Variance: 0.0085
# Loss: 0.0867, Value Loss: 0.0867, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2552, Frame: 2732, Explained Variance: -0.0000
# Loss: 0.0740, Value Loss: 0.0740, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2550, Frame: 2733, Explained Variance: 0.0040
# Loss: 0.0712, Value Loss: 0.0712, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2550, Frame: 2733, Explained Variance: -0.0001
# Loss: 0.0412, Value Loss: 0.0412, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2549, Frame: 2734, Explained Variance: 0.0071
# Loss: 0.0739, Value Loss: 0.0739, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2549, Frame: 2734, Explained Variance: -0.0001
# Loss: 1.5866, Value Loss: 1.5866, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2548, Frame: 2735, Explained Variance: 0.0002
# Loss: 0.1395, Value Loss: 0.1395, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2548, Frame: 2735, Explained Variance: -0.0000
# Loss: 16.7313, Value Loss: 16.7313, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2547, Frame: 2736, Explained Variance: 0.0000
# Loss: 0.0263, Value Loss: 0.0263, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2547, Frame: 2736, Explained Variance: -0.0001
# Loss: 0.0415, Value Loss: 0.0415, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2545, Frame: 2737, Explained Variance: 0.0067
# Loss: 1.2103, Value Loss: 1.2103, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2545, Frame: 2737, Explained Variance: -0.0000
# Loss: 0.0335, Value Loss: 0.0335, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2544, Frame: 2738, Explained Variance: 0.0090
# Loss: 0.0258, Value Loss: 0.0258, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2544, Frame: 2738, Explained Variance: 0.0000
# Loss: 0.0478, Value Loss: 0.0478, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2543, Frame: 2739, Explained Variance: 0.0058
# Loss: 0.0627, Value Loss: 0.0627, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2543, Frame: 2739, Explained Variance: 0.0000
# Loss: 0.0722, Value Loss: 0.0722, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2541, Frame: 2740, Explained Variance: 0.0031
# Loss: 3.9607, Value Loss: 3.9607, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2541, Frame: 2740, Explained Variance: 0.0000
# Loss: 0.0392, Value Loss: 0.0392, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2540, Frame: 2741, Explained Variance: 0.0069
# Loss: 0.2047, Value Loss: 0.2047, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2540, Frame: 2741, Explained Variance: -0.0000
# Loss: 0.0212, Value Loss: 0.0212, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2539, Frame: 2742, Explained Variance: 0.0129
# Loss: 0.6725, Value Loss: 0.6725, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2539, Frame: 2742, Explained Variance: -0.0000
# Loss: 0.0521, Value Loss: 0.0521, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2538, Frame: 2743, Explained Variance: 0.0050
# Loss: 7.5557, Value Loss: 7.5557, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2538, Frame: 2743, Explained Variance: -0.0000
# Loss: 0.1987, Value Loss: 0.1987, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2536, Frame: 2744, Explained Variance: 0.0012
# Loss: 0.1519, Value Loss: 0.1519, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2536, Frame: 2744, Explained Variance: 0.0000
# Loss: 11.6280, Value Loss: 11.6280, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2535, Frame: 2745, Explained Variance: 0.0000
# Loss: 0.0738, Value Loss: 0.0738, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2535, Frame: 2745, Explained Variance: 0.0000
# Loss: 0.0660, Value Loss: 0.0660, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2534, Frame: 2746, Explained Variance: 0.0048
# Loss: 1.0546, Value Loss: 1.0546, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2534, Frame: 2746, Explained Variance: -0.0000
# Loss: 0.0272, Value Loss: 0.0272, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2533, Frame: 2747, Explained Variance: 0.0115
# Loss: 1.3016, Value Loss: 1.3016, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2533, Frame: 2747, Explained Variance: 0.0000
# Loss: 3.1234, Value Loss: 3.1234, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2531, Frame: 2748, Explained Variance: 0.0001
# Loss: 0.1036, Value Loss: 0.1036, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2531, Frame: 2748, Explained Variance: -0.0000
# Loss: 0.0464, Value Loss: 0.0464, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2530, Frame: 2749, Explained Variance: 0.0062
# Loss: 0.0433, Value Loss: 0.0433, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2530, Frame: 2749, Explained Variance: 0.0000
# Loss: 1.6708, Value Loss: 1.6708, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2529, Frame: 2750, Explained Variance: 0.0002
# Loss: 4.0540, Value Loss: 4.0540, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2529, Frame: 2750, Explained Variance: -0.0000
# Loss: 0.2593, Value Loss: 0.2593, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2528, Frame: 2751, Explained Variance: 0.0009
# Loss: 1.2021, Value Loss: 1.2021, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2528, Frame: 2751, Explained Variance: -0.0000
# Loss: 4.0454, Value Loss: 4.0454, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2526, Frame: 2752, Explained Variance: 0.0001
# Loss: 1.0124, Value Loss: 1.0124, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2526, Frame: 2752, Explained Variance: 0.0000
# Loss: 0.0282, Value Loss: 0.0282, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2525, Frame: 2753, Explained Variance: 0.0097
# Loss: 0.0197, Value Loss: 0.0197, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2525, Frame: 2753, Explained Variance: 0.0001
# Loss: 0.0343, Value Loss: 0.0343, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2524, Frame: 2754, Explained Variance: 0.0037
# Loss: 0.0805, Value Loss: 0.0805, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2524, Frame: 2754, Explained Variance: -0.0001
# Loss: 0.0682, Value Loss: 0.0682, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2522, Frame: 2755, Explained Variance: -0.0000
# Loss: 0.0514, Value Loss: 0.0514, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2522, Frame: 2755, Explained Variance: -0.0000
# Loss: 0.4331, Value Loss: 0.4331, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2521, Frame: 2756, Explained Variance: 0.0003
# Loss: 0.1157, Value Loss: 0.1157, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2521, Frame: 2756, Explained Variance: -0.0001
# Loss: 0.0343, Value Loss: 0.0343, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2520, Frame: 2757, Explained Variance: 0.0052
# Loss: 0.1638, Value Loss: 0.1638, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2520, Frame: 2757, Explained Variance: -0.0000
# Loss: 0.0687, Value Loss: 0.0687, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2519, Frame: 2758, Explained Variance: 0.0027
# Loss: 8.8895, Value Loss: 8.8895, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2519, Frame: 2758, Explained Variance: -0.0000
# Loss: 0.0413, Value Loss: 0.0413, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2517, Frame: 2759, Explained Variance: 0.0040
# Loss: 3.9891, Value Loss: 3.9891, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2517, Frame: 2759, Explained Variance: -0.0000
# Loss: 3.0244, Value Loss: 3.0244, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2516, Frame: 2760, Explained Variance: 0.0000
# Loss: 0.1457, Value Loss: 0.1457, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2516, Frame: 2760, Explained Variance: -0.0000
# Loss: 0.0578, Value Loss: 0.0578, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2515, Frame: 2761, Explained Variance: 0.0024
# Loss: 1.3329, Value Loss: 1.3329, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2515, Frame: 2761, Explained Variance: -0.0000
# Loss: 0.0213, Value Loss: 0.0213, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2514, Frame: 2762, Explained Variance: 0.0063
# Loss: 2.7444, Value Loss: 2.7444, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2514, Frame: 2762, Explained Variance: -0.0000
# Loss: 3.2346, Value Loss: 3.2346, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2512, Frame: 2763, Explained Variance: 0.0000
# Loss: 0.0269, Value Loss: 0.0269, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2512, Frame: 2763, Explained Variance: -0.0005
# Loss: 1.6110, Value Loss: 1.6110, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2511, Frame: 2764, Explained Variance: 0.0001
# Loss: 1.9040, Value Loss: 1.9040, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2511, Frame: 2764, Explained Variance: -0.0000
# Loss: 0.0562, Value Loss: 0.0562, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2510, Frame: 2765, Explained Variance: 0.0031
# Loss: 0.0256, Value Loss: 0.0256, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2510, Frame: 2765, Explained Variance: -0.0003
# Loss: 0.0213, Value Loss: 0.0213, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2509, Frame: 2766, Explained Variance: 0.0069
# Loss: 2.4500, Value Loss: 2.4500, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2509, Frame: 2766, Explained Variance: -0.0000
# Loss: 8.5156, Value Loss: 8.5156, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2507, Frame: 2767, Explained Variance: 0.0000
# Loss: 0.0205, Value Loss: 0.0205, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2507, Frame: 2767, Explained Variance: -0.0007
# Loss: 14.3941, Value Loss: 14.3941, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2506, Frame: 2768, Explained Variance: 0.0000
# Loss: 6.6140, Value Loss: 6.6140, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2506, Frame: 2768, Explained Variance: -0.0000
# Loss: 0.0622, Value Loss: 0.0622, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2505, Frame: 2769, Explained Variance: 0.0024
# Loss: 0.0462, Value Loss: 0.0462, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2505, Frame: 2769, Explained Variance: -0.0003
# Loss: 0.0643, Value Loss: 0.0643, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2504, Frame: 2770, Explained Variance: 0.0016
# Loss: 0.0404, Value Loss: 0.0404, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2504, Frame: 2770, Explained Variance: -0.0005
# Loss: 0.0557, Value Loss: 0.0557, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2502, Frame: 2771, Explained Variance: 0.0014
# Loss: 0.6894, Value Loss: 0.6894, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2502, Frame: 2771, Explained Variance: -0.0000
# Loss: 0.0423, Value Loss: 0.0423, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2501, Frame: 2772, Explained Variance: -0.0018
# Loss: 0.6604, Value Loss: 0.6604, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2501, Frame: 2772, Explained Variance: -0.0000
# Loss: 0.0667, Value Loss: 0.0667, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2500, Frame: 2773, Explained Variance: -0.0031
# Loss: 0.0204, Value Loss: 0.0204, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2500, Frame: 2773, Explained Variance: -0.0007
# Loss: 0.0423, Value Loss: 0.0423, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2499, Frame: 2774, Explained Variance: -0.0094
# Loss: 3.9623, Value Loss: 3.9623, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2499, Frame: 2774, Explained Variance: -0.0000
# Loss: 0.0661, Value Loss: 0.0661, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2497, Frame: 2775, Explained Variance: -0.0041
# Loss: 0.0422, Value Loss: 0.0422, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2497, Frame: 2775, Explained Variance: -0.0002
# Loss: 11.8521, Value Loss: 11.8521, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2496, Frame: 2776, Explained Variance: -0.0000
# Loss: 0.1225, Value Loss: 0.1225, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2496, Frame: 2776, Explained Variance: -0.0001
# Loss: 0.0412, Value Loss: 0.0412, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2495, Frame: 2777, Explained Variance: -0.0103
# Loss: 0.1255, Value Loss: 0.1255, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2495, Frame: 2777, Explained Variance: -0.0001
# Loss: 3.1055, Value Loss: 3.1055, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2494, Frame: 2778, Explained Variance: -0.0001
# Loss: 0.0900, Value Loss: 0.0900, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2494, Frame: 2778, Explained Variance: -0.0001
# Loss: 8.2639, Value Loss: 8.2639, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2492, Frame: 2779, Explained Variance: -0.0000
# Loss: 0.0320, Value Loss: 0.0320, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2492, Frame: 2779, Explained Variance: -0.0002
# Loss: 2.9729, Value Loss: 2.9729, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2491, Frame: 2780, Explained Variance: -0.0001
# Loss: 1.2815, Value Loss: 1.2815, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2491, Frame: 2780, Explained Variance: -0.0000
# Loss: 3.9642, Value Loss: 3.9642, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2490, Frame: 2781, Explained Variance: -0.0001
# Loss: 0.0378, Value Loss: 0.0378, Entropy: 1.6094, LR: 0.000100, Epsilon: 0.2490, Frame: 2781, Explained Variance: -0.0003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 217
#     214     wandb.finish()
#     216 if __name__ == "__main__":
# --> 217     evaluate_agents(Agent, Agent, seed=42, training=True, games_to_play=50, validate_every=5)
#
# Cell In[9], line 99, in evaluate_agents(agent_1_cls, agent_2_cls, seed, training, games_to_play, validate_every)
#      97 for agent in [player_0, player_1]:
#      98     if obs[agent.player] is not None:
# ---> 99         actions[agent.player] = agent.act(step=step, obs=obs[agent.player])
#     100     else:
#     101         actions[agent.player] = np.zeros((env_cfg["max_units"], 3), dtype=int)
#
# Cell In[2], line 594, in Agent.act(self, step, obs, remainingOverageTime)
#     592 points = int(obs["team_points"][self.team_id])
#     593 reward = max(0, points - self.fleet.points)
# --> 594 self.space.update(step, obs, self.team_id, reward)
#     595 self.fleet.update(obs, self.space)
#     596 self.opp_fleet.update(obs, self.space)
#
# Cell In[2], line 212, in Space.update(self, step, obs, team_id, team_reward)
#     210 self.move_obstacles(step)
#     211 self._update_map(obs)
# --> 212 self._update_relic_map(step, obs, team_id, team_reward)
#
# Cell In[2], line 248, in Space._update_relic_map(self, step, obs, team_id, team_reward)
#     246 self._update_reward_status_from_relics_distribution()
#     247 self._update_reward_results(obs, team_id, team_reward)
# --> 248 self._update_reward_status_from_reward_results()
#
# Cell In[2], line 255, in Space._update_reward_status_from_reward_results(self)
#     253 known_reward = 0
#     254 for n in result["nodes"]:
# --> 255     if n.explored_for_reward and not n.reward:
#     256         continue
#     257     if n.reward:
#
# Cell In[2], line 129, in Node.reward(self)
#     125 @property
#     126 def relic(self):
#     127     return self._relic
# --> 129 @property
#     130 def reward(self):
#     131     return self._reward
#     133 @property
#     134 def explored_for_relic(self):
#
# KeyboardInterrupt:
